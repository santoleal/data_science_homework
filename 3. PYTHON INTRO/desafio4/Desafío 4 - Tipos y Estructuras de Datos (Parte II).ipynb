# %% [markdown]
# # **DESAFÍO Nº4: TIPOS Y ESTRUCTURAS DE DATOS (PARTE II)**
# ### **Módulo 3: Python para análisis de datos**
# #### *Carrera Data Science - G-68 - Desafio Latam*
# #### Estudiante: Felipe Leal Arancibia

# %% [markdown]
# Para desarrollar este desafío necesitarás el archivo resumen_resultados_astronautas.csv
#
# ● El IMC es una medida importante que nos ayuda a determinar si una persona tiene un peso saludable para poder ser un astronauta. Para calcularlo se utiliza la fórmula:
#
#         IMC = m / h*h
#
# Donde m corresponde al peso del astronauta en kilogramos, y h su estatura en metros
#
# El rendimiento en las diferentes evaluaciones permitirá también aceptar o rechazar a los postulantes. Para ello:
#
# 1. Crea un DataFrame con el archivo entregado.
# 2. Crea la columna "IMC" usando la fórmula entregada.
# 3. Crea la columna "promedio_evaluaciones" con el promedio de las 4 columnas  de evaluaciones. Si el IMC está entre 18.5 y 24.9, entonces el candidato tendrá un IMC adecuado para ser astronauta. Filtra el DataFrame para obtener solo aquellas filas donde el IMC esté dentro de los límites entregados.
# 4. El promedio de las 4 evaluaciones debe ser mayor o igual a 87. Filtra el DataFrame resultante y agrega esta condición al filtro aplicado en el paso anterior.
# 5. Reinicia el índice del DataFrame resultante.
# 6. Modifica el valor de la columna "califica", para que diga "Si" en todas las filas del DataFrame resultante.
# 7. Exporta el DataFrame resultante a un archivo .csv separado por comas con el nombre "astronautas_calificados.csv".

# %% [markdown]
# ### 1. Crea un Dataframe con el archivo entregado

# %%
import pandas as pd

astronautas = pd.read_csv('resumen_resultados_astronautas.csv')

type(astronautas)  # Se confirma que es un DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
astronautas.index
# Out:
# RangeIndex(start=0, stop=32, step=1)

# %%
astronautas.head()
# Out:
#             nombre  edad  peso  altura  evaluacion_fisica  \
# 0    Alana Morillo    32    75     180                 93
# 1   Fátima Tafalla    27    68     167                 82
# 2       Sofía Puig    29    80     185                 85
# 3  Valentina Tasis    30    65     175                 90
# 4   Regina Cicerón    31    76     183                 89
#
#    evaluacion_psicologica  evaluacion_adaptativa  evaluacion_medica  \
# 0                      88                     78                 89
# 1                      95                     81                 87
# 2                      80                     90                 91
# 3                      91                     85                 92
# 4                      87                     83                 90
#
#    anos_experiencia califica
# 0                 6       Si
# 1                 4       Si
# 2                 3       Si
# 3                 2       No
# 4                 7       Si

# %% [markdown]
# ### 2. Crea la columna "IMC" usando la fórmula entregada.

# %%
# Fórmula: IMC = m / h*h

astronautas["IMC"] = round(astronautas["peso"] / ((astronautas["altura"] / 100)**2), 1)

# %%
astronautas.head()
# Out:
#             nombre  edad  peso  altura  evaluacion_fisica  \
# 0    Alana Morillo    32    75     180                 93
# 1   Fátima Tafalla    27    68     167                 82
# 2       Sofía Puig    29    80     185                 85
# 3  Valentina Tasis    30    65     175                 90
# 4   Regina Cicerón    31    76     183                 89
#
#    evaluacion_psicologica  evaluacion_adaptativa  evaluacion_medica  \
# 0                      88                     78                 89
# 1                      95                     81                 87
# 2                      80                     90                 91
# 3                      91                     85                 92
# 4                      87                     83                 90
#
#    anos_experiencia califica   IMC
# 0                 6       Si  23.1
# 1                 4       Si  24.4
# 2                 3       Si  23.4
# 3                 2       No  21.2
# ...

# %% [markdown]
# ### 3. Crea la columna "promedio_evaluaciones" con el promedio de las 4 columnas  de evaluaciones. Si el IMC está entre 18.5 y 24.9, entonces el candidato tendrá un IMC adecuado para ser astronauta. Filtra el DataFrame para obtener solo aquellas filas donde el IMC esté dentro de los límites entregados.

# %%
astronautas["Promedio_evaluaciones"] = round((astronautas[["evaluacion_fisica", "evaluacion_psicologica", "evaluacion_adaptativa", "evaluacion_medica"]].mean(axis=1)),1)

astronautas.columns
# Out:
# Index(['nombre', 'edad', 'peso', 'altura', 'evaluacion_fisica',
#        'evaluacion_psicologica', 'evaluacion_adaptativa', 'evaluacion_medica',
#        'anos_experiencia', 'califica', 'IMC', 'Promedio_evaluaciones'],
#       dtype='object')

# %%
imc_adecuado = astronautas.query("IMC >= 18.5 and IMC <= 24.9 ")

imc_adecuado
# Out:
#                   nombre  edad  peso  altura  evaluacion_fisica  \
# 0          Alana Morillo    32    75     180                 93
# 1         Fátima Tafalla    27    68     167                 82
# 2             Sofía Puig    29    80     185                 85
# 3        Valentina Tasis    30    65     175                 90
# 4         Regina Cicerón    31    76     183                 89
# 5       Amaya de la Cruz    26    64     170                 80
# 6         María Juderías    28    78     182                 88
# 8      Consuela Arboleda    33    77     188                 94
# 9      María José Franco    29    70     175                 87
# 10        Emanuel Gálvez    27    73     181                 84
# 11      Alberto Graciani    28    62     163                 81
# 12  Patricio Encarnación    30    81     190                 93
# 13    Cristóbal Miralles    31    72     174                 88
# 14         Pablo Cotilla    27    75     178                 86
# ...

# %%
fuera_de_rango = astronautas.query("IMC <= 18.5 or IMC >= 24.9 ")

fuera_de_rango
# Out:
#              nombre  edad  peso  altura  evaluacion_fisica  \
# 7     Perla Alcocer    30    71     168                 86
# 19       José París    40    68     163                 78
# 22   Óliver Fonseca    38    80     164                 77
# 26  Fernando Gálvez    25    72     168                 88
#
#     evaluacion_psicologica  evaluacion_adaptativa  evaluacion_medica  \
# 7                       92                     82                 88
# 19                      85                     85                 77
# 22                      88                     90                 89
# 26                      88                     89                 83
#
#     anos_experiencia califica   IMC  Promedio_evaluaciones
# 7                  3       No  25.2                   87.0
# 19                 8       No  25.6                   81.2
# 22                 9       No  29.7                   86.0
# 26                 2       Si  25.5                   87.0

# %% [markdown]
# ### 4. El promedio de las 4 evaluaciones debe ser mayor o igual a 87. Filtra el DataFrame resultante y agrega esta condición al filtro aplicado en el paso anterior.

# %%
imc_adecuado.query("Promedio_evaluaciones >= 87", inplace=True)
# Out:
# /tmp/ipykernel_136676/3721452150.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imc_adecuado.query("Promedio_evaluaciones >= 87", inplace=True)

# %%
imc_adecuado
# Out:
#                   nombre  edad  peso  altura  evaluacion_fisica  \
# 0          Alana Morillo    32    75     180                 93
# 3        Valentina Tasis    30    65     175                 90
# 4         Regina Cicerón    31    76     183                 89
# 6         María Juderías    28    78     182                 88
# 8      Consuela Arboleda    33    77     188                 94
# 12  Patricio Encarnación    30    81     190                 93
# 13    Cristóbal Miralles    31    72     174                 88
# 16      Nicolás Cambeiro    29    68     175                 88
# 18         Samuel Gálvez    22    74     183                 91
# 23  Christopher Berganza    23    70     173                 92
# 28           Alexia Gaos    21    69     169                 93
# 29         Fátima Varela    33    73     182                 91
#
#     evaluacion_psicologica  evaluacion_adaptativa  evaluacion_medica  \
# ...

# %% [markdown]
# ### 5. Reinicia el índice del DataFrame resultante.

# %%
astronautas_calificados = imc_adecuado.reset_index(drop=True)

astronautas_calificados
# Out:
#                   nombre  edad  peso  altura  evaluacion_fisica  \
# 0          Alana Morillo    32    75     180                 93
# 1        Valentina Tasis    30    65     175                 90
# 2         Regina Cicerón    31    76     183                 89
# 3         María Juderías    28    78     182                 88
# 4      Consuela Arboleda    33    77     188                 94
# 5   Patricio Encarnación    30    81     190                 93
# 6     Cristóbal Miralles    31    72     174                 88
# 7       Nicolás Cambeiro    29    68     175                 88
# 8          Samuel Gálvez    22    74     183                 91
# 9   Christopher Berganza    23    70     173                 92
# 10           Alexia Gaos    21    69     169                 93
# 11         Fátima Varela    33    73     182                 91
#
#     evaluacion_psicologica  evaluacion_adaptativa  evaluacion_medica  \
# ...

# %% [markdown]
# ### 6. Modifica el valor de la columna "califica", para que diga "Si" en todas las filas del DataFrame resultante.

# %%
astronautas_calificados["califica"] = astronautas_calificados["califica"].replace(["No"], "Si")

astronautas_calificados
# Out:
#                   nombre  edad  peso  altura  evaluacion_fisica  \
# 0          Alana Morillo    32    75     180                 93
# 1        Valentina Tasis    30    65     175                 90
# 2         Regina Cicerón    31    76     183                 89
# 3         María Juderías    28    78     182                 88
# 4      Consuela Arboleda    33    77     188                 94
# 5   Patricio Encarnación    30    81     190                 93
# 6     Cristóbal Miralles    31    72     174                 88
# 7       Nicolás Cambeiro    29    68     175                 88
# 8          Samuel Gálvez    22    74     183                 91
# 9   Christopher Berganza    23    70     173                 92
# 10           Alexia Gaos    21    69     169                 93
# 11         Fátima Varela    33    73     182                 91
#
#     evaluacion_psicologica  evaluacion_adaptativa  evaluacion_medica  \
# ...

# %% [markdown]
# ### 7. Exporta el DataFrame resultante a un archivo .csv separado por comas con el nombre "astronautas_calificados.csv".

# %%
astronautas_calificados.to_csv("astronautas_calificados.csv", index=False, sep=",")

# %% [markdown]
# ### ____o_O_
#
# ### Saludos y gracias!
#
# ### ___________O_o_
